# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# DEVINENI SRI VENKATRAYA CHOWDARY
# STUDENT

# %% [markdown]
# _I am interested in data science because of its ability to draw conclusions from the input fed to it mimicking the human brain in a more complex and bigger environments.Developing a model strikes the idea of a brain growing._

# %% [markdown]
# ### I am going to concatenate two strings

# %%
"string"+"array"
# Out:
# 'stringarray'

# %% [markdown]
#  - Hope you are doing well
#  - IBM Data Science course is elaborate and super informatory
#      1. I have something to tell you
#      2. Data Science is really interesting
#      3. It has lot of applications
# | colour | price | sale percentage |
# | --- | --- | --- |
# | red | 1000 | 99 |
# ~You can do this~
